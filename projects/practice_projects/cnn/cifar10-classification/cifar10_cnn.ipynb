# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
model.add(Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_32 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 1,341,226
# Trainable params: 1,341,226
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=20,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
#  - 24s - loss: 1.6259 - acc: 0.4119 - val_loss: 1.3735 - val_acc: 0.5110
#
# Epoch 00001: val_loss improved from inf to 1.37354, saving model to model.weights.best.hdf5
# Epoch 2/20
#  - 21s - loss: 1.1367 - acc: 0.6000 - val_loss: 1.0934 - val_acc: 0.6260
#
# Epoch 00002: val_loss improved from 1.37354 to 1.09337, saving model to model.weights.best.hdf5
# Epoch 3/20
#  - 21s - loss: 0.9860 - acc: 0.6583 - val_loss: 0.9225 - val_acc: 0.6732
#
# Epoch 00003: val_loss improved from 1.09337 to 0.92250, saving model to model.weights.best.hdf5
# Epoch 4/20
#  - 21s - loss: 0.9255 - acc: 0.6853 - val_loss: 0.9825 - val_acc: 0.6626
#
# Epoch 00004: val_loss did not improve from 0.92250
# Epoch 5/20
#  - 22s - loss: 0.9081 - acc: 0.6925 - val_loss: 0.9534 - val_acc: 0.6970
#
# Epoch 00005: val_loss did not improve from 0.92250
# Epoch 6/20
#  - 22s - loss: 0.9091 - acc: 0.6994 - val_loss: 0.9023 - val_acc: 0.7176
#
# Epoch 00006: val_loss improved from 0.92250 to 0.90231, saving model to model.weights.best.hdf5
# Epoch 7/20
#  - 22s - loss: 0.9205 - acc: 0.6924 - val_loss: 0.8293 - val_acc: 0.7316
#
# Epoch 00007: val_loss improved from 0.90231 to 0.82934, saving model to model.weights.best.hdf5
# Epoch 8/20
#  - 21s - loss: 0.9337 - acc: 0.6891 - val_loss: 1.2421 - val_acc: 0.5704
#
# Epoch 00008: val_loss did not improve from 0.82934
# Epoch 9/20
#  - 21s - loss: 0.9415 - acc: 0.6888 - val_loss: 1.1472 - val_acc: 0.6260
#
# Epoch 00009: val_loss did not improve from 0.82934
# Epoch 10/20
#  - 22s - loss: 0.9675 - acc: 0.6808 - val_loss: 1.2112 - val_acc: 0.6470
#
# Epoch 00010: val_loss did not improve from 0.82934
# Epoch 11/20
#  - 21s - loss: 0.9674 - acc: 0.6805 - val_loss: 0.9793 - val_acc: 0.6834
#
# Epoch 00011: val_loss did not improve from 0.82934
# Epoch 12/20
#  - 22s - loss: 0.9972 - acc: 0.6737 - val_loss: 0.8944 - val_acc: 0.6832
#
# Epoch 00012: val_loss did not improve from 0.82934
# Epoch 13/20
#  - 21s - loss: 1.0181 - acc: 0.6680 - val_loss: 1.7762 - val_acc: 0.5260
#
# Epoch 00013: val_loss did not improve from 0.82934
# Epoch 14/20
#  - 21s - loss: 1.0397 - acc: 0.6630 - val_loss: 1.0504 - val_acc: 0.6618
#
# Epoch 00014: val_loss did not improve from 0.82934
# Epoch 15/20
#  - 20s - loss: 1.0642 - acc: 0.6567 - val_loss: 0.9539 - val_acc: 0.6844
#
# Epoch 00015: val_loss did not improve from 0.82934
# Epoch 16/20
#  - 21s - loss: 1.0855 - acc: 0.6497 - val_loss: 0.8284 - val_acc: 0.7384
#
# Epoch 00016: val_loss improved from 0.82934 to 0.82839, saving model to model.weights.best.hdf5
# Epoch 17/20
#  - 21s - loss: 1.1210 - acc: 0.6402 - val_loss: 1.1435 - val_acc: 0.6146
#
# Epoch 00017: val_loss did not improve from 0.82839
# Epoch 18/20
#  - 20s - loss: 1.1397 - acc: 0.6304 - val_loss: 1.0661 - val_acc: 0.6310
#
# Epoch 00018: val_loss did not improve from 0.82839
# Epoch 19/20
#  - 22s - loss: 1.1609 - acc: 0.6209 - val_loss: 1.0669 - val_acc: 0.6468
#
# Epoch 00019: val_loss did not improve from 0.82839
# Epoch 20/20
#  - 22s - loss: 1.1890 - acc: 0.6140 - val_loss: 0.9995 - val_acc: 0.6622
#
# Epoch 00020: val_loss did not improve from 0.82839

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7198

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
